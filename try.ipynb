# %%
# !pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 261.2 kB/s eta 0:00:00m eta 0:00:010:00:02
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 KB 371.4 kB/s eta 0:00:000:00:010:00:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 247.6 kB/s eta 0:00:00m eta 0:00:010:00:03
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# ...

# %%
# !pip install lxml

# %%
import pandas as pd

# %%
url = "https://en.wikipedia.org/wiki/List_of_largest_universities"

tables = pd.read_html(url)

# %%
len(tables)
# Out:
# 2

# %%
tables[1]
# Out:
#            Country                        University Founded    Type  \
# 0          Albania              University of Tirana    1957  Public
# 1          Algeria            Constantine University    1978  Public
# 2           Angola         Agostinho Neto University    1962  Public
# 3        Argentina        University of Buenos Aires    1821  Public
# 4        Australia                 Monash University    1958  Public
# ..             ...                               ...     ...     ...
# 64          Turkey                Anadolu University    1958  Public
# 65  United Kingdom                   Open University    1969  Public
# 66   United States              Texas A&M University    1876  Public
# 67         Uruguay        University of the Republic    1949  Public
# 68       Venezuela  Universidad Central de Venezuela    1721  Public
#
#    Enrollment       Ref
# 0       35000       NaN
# 1       85000       NaN
# 2       29827       NaN
# 3      311175       NaN
# ...

# %%
df = tables[1]

# %%
df.head()
# Out:
#      Country                  University Founded    Type Enrollment  Ref
# 0    Albania        University of Tirana    1957  Public      35000  NaN
# 1    Algeria      Constantine University    1978  Public      85000  NaN
# 2     Angola   Agostinho Neto University    1962  Public      29827  NaN
# 3  Argentina  University of Buenos Aires    1821  Public     311175  NaN
# 4  Australia           Monash University    1958  Public      73807  [1]

# %%
df.sample(5)
# Out:
#          Country                                      University Founded  \
# 52        Russia            Modern University for the Humanities    1992
# 35         Kenya                           University of Nairobi    1970
# 53  Saudi Arabia                       King Abdulaziz University    1976
# 24        Greece  National and Kapodistrian University of Athens    1837
# 21       Finland                          University of Helsinki    1640
#
#        Type Enrollment   Ref
# 52  Private     200000   NaN
# 35   Public      84000  [20]
# 53   Public     177234  [31]
# 24   Public     104000  [10]
# 21   Public      36500   NaN
